# %% [markdown]
# # Working with CSV Files
#
# The `csv` module in Python implements classes to read and write tabular data in CSV format. It allows programmers to say, "read data from this file which was generated by Excel," or "write this data in the format preferred by Excel," without knowing the precise details of the CSV format used by Excel.
#
# Let's begin with the basics.
#
# ### Import the csv module
#
# First, import the csv module:

# %%
import csv

# %% [markdown]
# ### Reading a CSV file
#
# To read a CSV file, you use the `csv.reader` function:

# %%
import os 
file_path = os.path.join("..", "data", "Marketing_Raw_Data.csv")

# %%
with open(file_path, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Date', 'Day_Name', 'Visitors', 'Revenue', 'Marketing Spend', 'Promo']
# ['09/11/2020', 'Monday', '707', '5211', '651.375', 'No Promo']
# ['10/11/2020', 'Tuesday', '1455', '10386', '1298.25', 'Promotion Red']
# ['11/11/2020', 'Wednesday', '1520', '12475', '1559.375', 'Promotion Blue']
# ['12/11/2020', 'Thursday', '1726', '14414', '1801.75', 'No Promo']
# ['13/11/2020', 'Friday', '2134', '20916', '2614.5', 'No Promo']
# ['14/11/2020', 'Saturday', '1316', '12996', '1444', 'Promotion Blue']
# ['15/11/2020', 'Sunday', '1287', '11929', '1325.444444', 'Promotion Blue']
# ['16/11/2020', 'Monday', '1548', '10072', '1119.111111', 'No Promo']
# ['17/11/2020', 'Tuesday', '1448', '12016', '1092.363636', 'Promotion Blue']
# ['18/11/2020', 'Wednesday', '1362', '9067', '906.7', 'No Promo']
# ['19/11/2020', 'Thursday', '2321', '17660', '1605.454545', 'No Promo']
# ['20/11/2020', 'Friday', '1819', '15188', '1687.555556', 'Promotion Red']
# ['21/11/2020', 'Saturday', '1180', '7813', '710.2727273', 'No Promo']
# ['22/11/2020', 'Sunday', '2138', '21963', '2745.375', 'Promotion Red']
# ['23/11/2020', 'Monday', '2632', '34278', '4284.75', 'Promotion Blue']
# ['24/11/2020', 'Tuesday', '1752', '18650', '1695.454545', 'Promotion Blue']
# ['25/11/2020', 'Wednesday', '627', '5574', '696.75', 'Promotion Blue']
# ['26/11/2020', 'Thursday', '2105', '17294', '1572.181818', 'Promotion Red']
# ['27/11/2020', 'Friday', '1671', '14760', '1845', 'Promotion Red']
# ['28/11/2020', 'Saturday', '1105', '8091', '899', 'Promotion Red']
# ['29/11/2020', 'Sunday', '1698', '10647', '1330.875', 'Promotion Red']
# ['30/11/2020', 'Monday', '1541', '9144', '1016', 'No Promo']
# ['01/12/2020', 'Tuesday', '1245', '8307', '923', 'No Promo']
# ['02/12/2020', 'Wednesday', '1955', '14254', '1425.4', 'Promotion Red']
# ['03/12/2020', 'Thursday', '2171', '16644', '1664.4', 'No Promo']
# ['04/12/2020', 'Friday', '1975', '20607', '2575.875', 'Promotion Blue']
# ['05/12/2020', 'Saturday', '1186', '7765', '776.5', 'No Promo']
# ['06/12/2020', 'Sunday', '1822', '10075', '915.9090909', 'Promotion Red']
# ['07/12/2020', 'Monday', '1584', '9612', '961.2', 'Promotion Red']
# ['08/12/2020', 'Tuesday', '1961', '11601', '1450.125', 'No Promo']
# ['09/12/2020', 'Wednesday', '2464', '16300', '1811.111111', 'No Promo']
# ['10/12/2020', 'Thursday', '2394', '17740', '1971.111111', 'No Promo']
# ['11/12/2020', 'Friday', '1322', '10140', '1267.5', 'No Promo']
# ['12/12/2020', 'Saturday', '1167', '9097', '1010.777778', 'Promotion Blue']
# ['13/12/2020', 'Sunday', '1163', '8802', '880.2', 'Promotion Blue']
# ['14/12/2020', 'Monday', '1772', '11679', '1297.666667', 'Promotion Red']
# ['15/12/2020', 'Tuesday', '1740', '11952', '1086.545455', 'Promotion Red']
# ['16/12/2020', 'Wednesday', '1317', '9213', '1023.666667', 'No Promo']
# ['17/12/2020', 'Thursday', '2330', '17618', '1601.636364', 'No Promo']
# ['18/12/2020', 'Friday', '2056', '18161', '2270.125', 'Promotion Blue']
# ['19/12/2020', 'Saturday', '1191', '8800', '880', 'Promotion Red']
# ['20/12/2020', 'Sunday', '1828', '11737', '1304.111111', 'No Promo']
# ['21/12/2020', 'Monday', '1605', '12038', '1203.8', 'Promotion Blue']
# ['22/12/2020', 'Tuesday', '1571', '10245', '1024.5', 'Promotion Red']
# ['23/12/2020', 'Wednesday', '1288', '11817', '1181.7', 'Promotion Blue']
# ['24/12/2020', 'Thursday', '2556', '19550', '1955', 'No Promo']
# ['25/12/2020', 'Friday', '2152', '21031', '2336.777778', 'Promotion Blue']
# ['26/12/2020', 'Saturday', '2678', '36283', '4535.375', 'Promotion Blue']
# ['27/12/2020', 'Sunday', '2020', '23014', '2557.111111', 'Promotion Blue']
# ['28/12/2020', 'Monday', '1480', '8611', '782.8181818', 'No Promo']
# ['29/12/2020', 'Tuesday', '1226', '7793', '779.3', 'Promotion Red']
# ['30/12/2020', 'Wednesday', '1328', '9180', '918', 'Promotion Red']
# ['31/12/2020', 'Thursday', '2295', '19280', '2410', 'No Promo']
# ['01/01/2021', 'Friday', '2032', '21428', '1948', 'Promotion Blue']
# ['02/01/2021', 'Saturday', '1030', '9062', '1006.888889', 'Promotion Blue']
# ['03/01/2021', 'Sunday', '1442', '9952', '1244', 'Promotion Blue']
# ['04/01/2021', 'Monday', '1476', '8563', '1070.375', 'No Promo']
# ['05/01/2021', 'Tuesday', '1272', '9418', '856.1818182', 'Promotion Red']
# ['06/01/2021', 'Wednesday', '2054', '25766', '2862.888889', 'Promotion Red']
# ['07/01/2021', 'Thursday', '4139', '30146', '3014.6', 'No Promo']
# ['08/01/2021', 'Friday', '2286', '15962', '1596.2', 'No Promo']
# ['09/01/2021', 'Saturday', '1371', '11249', '1406.125', 'Promotion Blue']
# ['10/01/2021', 'Sunday', '1484', '12129', '1516.125', 'Promotion Red']
# ['11/01/2021', 'Monday', '1571', '7300', '912.5', 'No Promo']
# ['12/01/2021', 'Tuesday', '1454', '8702', '870.2', 'Promotion Red']
# ['13/01/2021', 'Wednesday', '1243', '7509', '834.3333333', 'No Promo']
# ['14/01/2021', 'Thursday', '2753', '22797', '2072.454545', 'Promotion Red']
# ['15/01/2021', 'Friday', '2312', '21245', '2655.625', 'Promotion Blue']
# ['16/01/2021', 'Saturday', '1414', '11699', '1169.9', 'Promotion Blue']
# ['17/01/2021', 'Sunday', '1524', '9602', '960.2', 'Promotion Red']
# ['18/01/2021', 'Monday', '1469', '8633', '784.8181818', 'Promotion Red']
# ['19/01/2021', 'Tuesday', '1302', '7287', '728.7', 'Promotion Red']
# ['20/01/2021', 'Wednesday', '1659', '9261', '841.9090909', 'No Promo']
# ['21/01/2021', 'Thursday', '2120', '14770', '1641.111111', 'No Promo']
# ['22/01/2021', 'Friday', '2482', '24417', '2713', 'Promotion Blue']
# ['23/01/2021', 'Saturday', '1820', '11329', '1029.909091', 'No Promo']
# ['24/01/2021', 'Sunday', '1628', '12445', '1244.5', 'Promotion Red']
# ['25/01/2021', 'Monday', '1430', '10925', '1365.625', 'Promotion Blue']
# ['26/01/2021', 'Tuesday', '488', '2898', '322', 'No Promo']
# ['27/01/2021', 'Wednesday', '1084', '7049', '881.125', 'No Promo']
# ['28/01/2021', 'Thursday', '1864', '12832', '1425.777778', 'No Promo']
# ['29/01/2021', 'Friday', '1844', '13024', '1447.111111', 'No Promo']
# ['30/01/2021', 'Saturday', '1065', '7074', '786', 'No Promo']
# ['31/01/2021', 'Sunday', '1582', '9316', '1035.111111', 'No Promo']
# ['01/02/2021', 'Monday', '1407', '10479', '1047.9', 'Promotion Blue']
# ['02/02/2021', 'Tuesday', '1496', '12783', '1162.090909', 'Promotion Blue']
# ['03/02/2021', 'Wednesday', '2176', '18678', '1698', 'Promotion Blue']
# ['04/02/2021', 'Thursday', '2010', '14696', '1336', 'No Promo']
# ['05/02/2021', 'Friday', '2015', '17661', '2207.625', 'Promotion Red']
# ['06/02/2021', 'Saturday', '1488', '9095', '909.5', 'Promotion Red']
# ['07/02/2021', 'Sunday', '1608', '9199', '836.2727273', 'No Promo']
# ['08/02/2021', 'Monday', '1337', '9294', '929.4', 'No Promo']
# ['09/02/2021', 'Tuesday', '2266', '20860', '2317.777778', 'Promotion Blue']
# ['10/02/2021', 'Wednesday', '1925', '13602', '1511.333333', 'Promotion Blue']
# ['11/02/2021', 'Thursday', '826', '6546', '818.25', 'No Promo']
# ['12/02/2021', 'Friday', '1387', '10310', '937.2727273', 'No Promo']
# ['13/02/2021', 'Saturday', '599', '3392', '424', 'No Promo']
# ['14/02/2021', 'Sunday', '968', '5772', '524.7272727', 'Promotion Red']
# ['15/02/2021', 'Monday', '1482', '9987', '907.9090909', 'Promotion Red']
# ['16/02/2021', 'Tuesday', '1420', '8422', '935.7777778', 'No Promo']
# ['17/02/2021', 'Wednesday', '1171', '7809', '780.9', 'No Promo']
# ['18/02/2021', 'Thursday', '2395', '24247', '3030.875', 'Promotion Blue']
# ['19/02/2021', 'Friday', '2029', '14706', '1336.909091', 'No Promo']
# ['20/02/2021', 'Saturday', '1047', '6427', '803.375', 'No Promo']
# ['21/02/2021', 'Sunday', '1464', '7462', '829.1111111', 'No Promo']
# ['22/02/2021', 'Monday', '1428', '8371', '837.1', 'No Promo']
# ['23/02/2021', 'Tuesday', '1154', '9135', '1015', 'Promotion Red']
# ['24/02/2021', 'Wednesday', '1841', '13719', '1371.9', 'Promotion Blue']
# ['25/02/2021', 'Thursday', '2248', '20237', '2529.625', 'Promotion Blue']
# ['26/02/2021', 'Friday', '2553', '26608', '2418.909091', 'Promotion Blue']
# ['27/02/2021', 'Saturday', '1797', '12789', '1278.9', 'Promotion Red']
# ['28/02/2021', 'Sunday', '1912', '12036', '1337.333333', 'No Promo']
# ['01/03/2021', 'Monday', '1786', '13212', '1468', 'Promotion Blue']
# ['02/03/2021', 'Tuesday', '1096', '6155', '615.5', 'No Promo']
# ['03/03/2021', 'Wednesday', '1068', '8223', '822.3', 'Promotion Red']
# ['04/03/2021', 'Thursday', '1976', '16727', '1672.7', 'Promotion Blue']
# ['05/03/2021', 'Friday', '1806', '15474', '1719.333333', 'Promotion Blue']
# ['06/03/2021', 'Saturday', '1621', '12850', '1427.777778', 'Promotion Blue']
# ['07/03/2021', 'Sunday', '1001', '6681', '668.1', 'No Promo']
# ['08/03/2021', 'Monday', '1477', '8338', '926.4444444', 'No Promo']
# ['09/03/2021', 'Tuesday', '1401', '8569', '779', 'No Promo']
# ['10/03/2021', 'Wednesday', '2190', '17752', '1613.818182', 'Promotion Red']
# ['11/03/2021', 'Thursday', '2439', '25704', '2570.4', 'Promotion Blue']
# ['12/03/2021', 'Friday', '2220', '15302', '1912.75', 'No Promo']
# ['13/03/2021', 'Saturday', '2732', '28196', '3524.5', 'Promotion Blue']
# ['14/03/2021', 'Sunday', '967', '7878', '787.8', 'Promotion Blue']
# ['15/03/2021', 'Monday', '1544', '8083', '734.8181818', 'No Promo']
# ['16/03/2021', 'Tuesday', '1455', '7518', '939.75', 'No Promo']
# ['17/03/2021', 'Wednesday', '2194', '14608', '1826', 'No Promo']
# ['18/03/2021', 'Thursday', '1923', '14909', '1490.9', 'Promotion Red']
# ['19/03/2021', 'Friday', '685', '5903', '590.3', 'Promotion Red']
# ['20/03/2021', 'Saturday', '543', '4169', '521.125', 'Promotion Red']
# ['21/03/2021', 'Sunday', '1472', '9486', '862.3636364', 'Promotion Red']
# ['22/03/2021', 'Monday', '1368', '9209', '1151.125', 'Promotion Red']
# ['23/03/2021', 'Tuesday', '1454', '11494', '1277.111111', 'Promotion Blue']
# ['24/03/2021', 'Wednesday', '2080', '15190', '1519', 'Promotion Red']
# ['25/03/2021', 'Thursday', '2611', '22701', '2837.625', 'Promotion Red']
# ['26/03/2021', 'Friday', '2434', '22587', '2258.7', 'Promotion Blue']
# ['27/03/2021', 'Saturday', '1437', '7820', '868.8888889', 'No Promo']
# ['28/03/2021', 'Sunday', '1642', '14587', '1620.777778', 'Promotion Blue']
# ['29/03/2021', 'Monday', '1320', '9262', '842', 'Promotion Red']
# ['30/03/2021', 'Tuesday', '1363', '7794', '866', 'No Promo']
# ['31/03/2021', 'Wednesday', '2068', '14957', '1869.625', 'Promotion Red']
# ['01/04/2021', 'Thursday', '2311', '23368', '2921', 'Promotion Blue']
# ['02/04/2021', 'Friday', '2091', '15782', '1972.75', 'No Promo']
# ['03/04/2021', 'Saturday', '1532', '12027', '1336.333333', 'Promotion Red']
# ['04/04/2021', 'Sunday', '1406', '7545', '754.5', 'No Promo']
# ['05/04/2021', 'Monday', '1180', '8396', '763.2727273', 'Promotion Red']
# ['06/04/2021', 'Tuesday', '1244', '8828', '882.8', 'Promotion Red']
# ['07/04/2021', 'Wednesday', '1812', '16777', '1677.7', 'Promotion Red']
# ['08/04/2021', 'Thursday', '2273', '19843', '1803.909091', 'Promotion Red']
# ['09/04/2021', 'Friday', '2158', '23870', '2652.222222', 'Promotion Blue']
# ['10/04/2021', 'Saturday', '1625', '10431', '1043.1', 'No Promo']
# ['11/04/2021', 'Sunday', '1485', '11221', '1020.090909', 'Promotion Blue']
# ['12/04/2021', 'Monday', '1499', '10027', '1114.111111', 'Promotion Red']
# ['13/04/2021', 'Tuesday', '1511', '11484', '1148.4', 'Promotion Blue']
# ['14/04/2021', 'Wednesday', '1803', '16347', '1634.7', 'Promotion Blue']
# ['15/04/2021', 'Thursday', '2101', '15828', '1758.666667', 'No Promo']
# ['16/04/2021', 'Friday', '1915', '14714', '1337.636364', 'No Promo']
# ['17/04/2021', 'Saturday', '1509', '9520', '865.4545455', 'No Promo']
# ['18/04/2021', 'Sunday', '1399', '12251', '1531.375', 'Promotion Blue']
# ['19/04/2021', 'Monday', '1648', '9645', '964.5', 'Promotion Red']
# ['20/04/2021', 'Tuesday', '1154', '7058', '784.2222222', 'No Promo']
# ['21/04/2021', 'Wednesday', '1122', '6591', '732.3333333', 'No Promo']
# ['22/04/2021', 'Thursday', '2302', '24506', '2227.818182', 'Promotion Blue']
# ['23/04/2021', 'Friday', '1942', '14358', '1595.333333', 'No Promo']
# ['24/04/2021', 'Saturday', '1345', '9360', '850.9090909', 'Promotion Red']
# ['25/04/2021', 'Sunday', '1166', '11650', '1059.090909', 'Promotion Blue']
# ['26/04/2021', 'Monday', '1105', '8438', '843.8', 'No Promo']
# ['27/04/2021', 'Tuesday', '1256', '8046', '731.4545455', 'Promotion Red']
# ['28/04/2021', 'Wednesday', '1236', '9540', '1060', 'Promotion Blue']
# ['29/04/2021', 'Thursday', '2139', '22655', '2059.545455', 'Promotion Blue']
# ['30/04/2021', 'Friday', '1836', '19167', '1916.7', 'Promotion Blue']
# ['01/05/2021', 'Saturday', '1380', '8862', '805.6363636', 'No Promo']
# ['02/05/2021', 'Sunday', '1423', '12111', '1513.875', 'Promotion Red']
# ['03/05/2021', 'Monday', '1382', '11273', '1024.818182', 'Promotion Red']
# ['04/05/2021', 'Tuesday', '2152', '13805', '1533.888889', 'No Promo']
# ['05/05/2021', 'Wednesday', '1400', '11196', '1119.6', 'No Promo']
# ['06/05/2021', 'Thursday', '2244', '18611', '2067.888889', 'Promotion Red']
# ['07/05/2021', 'Friday', '2023', '14502', '1450.2', 'No Promo']
# ['08/05/2021', 'Saturday', '1483', '8975', '1121.875', 'No Promo']
# ['09/05/2021', 'Sunday', '1303', '6968', '871', 'No Promo']

# %% [markdown]
# Each row read from the csv file is returned as a list of strings. No automatic data type conversion is performed.
#
# ### Writing to a CSV file
#
# The `csv.writer` function provides two methods (`writerow` and `writerows`) for writing data to a CSV file:

# %%
data = [['Name', 'Age'], ['Bob', '23'], ['Alice', '25']]

with open('../data/file.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

# %%
data = [['Name', 'Age'], ['Bob', '23'], ['Alice', '25']]

with open('../data/file.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    for row in data:
        writer.writerow([row[0]])

# %% [markdown]
# `writerow` writes a single row to the csv file, while `writerows` writes all provided rows.
#
# ### Working with CSV files with headers
#
# The `csv` module provides a `DictReader` and a `DictWriter` class to help read and write to files where the first row is a header and each subsequent row is a dictionary.

# %%
# Reading a CSV file with headers
with open(file_path, 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
        print(row)

# Writing to a CSV file with headers
headers = ['Name', 'Age']
data = [{'Name': 'Bob', 'Age': '23'}, {'Name': 'Alice', 'Age': '25'}]

with open('../data/file.csv', 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=headers)
    writer.writeheader()
    writer.writerows(data)
# Out:
# {'Date': '09/11/2020', 'Day_Name': 'Monday', 'Visitors': '707', 'Revenue': '5211', 'Marketing Spend': '651.375', 'Promo': 'No Promo'}
# {'Date': '10/11/2020', 'Day_Name': 'Tuesday', 'Visitors': '1455', 'Revenue': '10386', 'Marketing Spend': '1298.25', 'Promo': 'Promotion Red'}
# {'Date': '11/11/2020', 'Day_Name': 'Wednesday', 'Visitors': '1520', 'Revenue': '12475', 'Marketing Spend': '1559.375', 'Promo': 'Promotion Blue'}
# {'Date': '12/11/2020', 'Day_Name': 'Thursday', 'Visitors': '1726', 'Revenue': '14414', 'Marketing Spend': '1801.75', 'Promo': 'No Promo'}
# {'Date': '13/11/2020', 'Day_Name': 'Friday', 'Visitors': '2134', 'Revenue': '20916', 'Marketing Spend': '2614.5', 'Promo': 'No Promo'}
# {'Date': '14/11/2020', 'Day_Name': 'Saturday', 'Visitors': '1316', 'Revenue': '12996', 'Marketing Spend': '1444', 'Promo': 'Promotion Blue'}
# {'Date': '15/11/2020', 'Day_Name': 'Sunday', 'Visitors': '1287', 'Revenue': '11929', 'Marketing Spend': '1325.444444', 'Promo': 'Promotion Blue'}
# {'Date': '16/11/2020', 'Day_Name': 'Monday', 'Visitors': '1548', 'Revenue': '10072', 'Marketing Spend': '1119.111111', 'Promo': 'No Promo'}
# {'Date': '17/11/2020', 'Day_Name': 'Tuesday', 'Visitors': '1448', 'Revenue': '12016', 'Marketing Spend': '1092.363636', 'Promo': 'Promotion Blue'}
# {'Date': '18/11/2020', 'Day_Name': 'Wednesday', 'Visitors': '1362', 'Revenue': '9067', 'Marketing Spend': '906.7', 'Promo': 'No Promo'}
# {'Date': '19/11/2020', 'Day_Name': 'Thursday', 'Visitors': '2321', 'Revenue': '17660', 'Marketing Spend': '1605.454545', 'Promo': 'No Promo'}
# {'Date': '20/11/2020', 'Day_Name': 'Friday', 'Visitors': '1819', 'Revenue': '15188', 'Marketing Spend': '1687.555556', 'Promo': 'Promotion Red'}
# {'Date': '21/11/2020', 'Day_Name': 'Saturday', 'Visitors': '1180', 'Revenue': '7813', 'Marketing Spend': '710.2727273', 'Promo': 'No Promo'}
# {'Date': '22/11/2020', 'Day_Name': 'Sunday', 'Visitors': '2138', 'Revenue': '21963', 'Marketing Spend': '2745.375', 'Promo': 'Promotion Red'}
# {'Date': '23/11/2020', 'Day_Name': 'Monday', 'Visitors': '2632', 'Revenue': '34278', 'Marketing Spend': '4284.75', 'Promo': 'Promotion Blue'}
# {'Date': '24/11/2020', 'Day_Name': 'Tuesday', 'Visitors': '1752', 'Revenue': '18650', 'Marketing Spend': '1695.454545', 'Promo': 'Promotion Blue'}
# {'Date': '25/11/2020', 'Day_Name': 'Wednesday', 'Visitors': '627', 'Revenue': '5574', 'Marketing Spend': '696.75', 'Promo': 'Promotion Blue'}
# {'Date': '26/11/2020', 'Day_Name': 'Thursday', 'Visitors': '2105', 'Revenue': '17294', 'Marketing Spend': '1572.181818', 'Promo': 'Promotion Red'}
# {'Date': '27/11/2020', 'Day_Name': 'Friday', 'Visitors': '1671', 'Revenue': '14760', 'Marketing Spend': '1845', 'Promo': 'Promotion Red'}
# {'Date': '28/11/2020', 'Day_Name': 'Saturday', 'Visitors': '1105', 'Revenue': '8091', 'Marketing Spend': '899', 'Promo': 'Promotion Red'}
# {'Date': '29/11/2020', 'Day_Name': 'Sunday', 'Visitors': '1698', 'Revenue': '10647', 'Marketing Spend': '1330.875', 'Promo': 'Promotion Red'}
# {'Date': '30/11/2020', 'Day_Name': 'Monday', 'Visitors': '1541', 'Revenue': '9144', 'Marketing Spend': '1016', 'Promo': 'No Promo'}
# {'Date': '01/12/2020', 'Day_Name': 'Tuesday', 'Visitors': '1245', 'Revenue': '8307', 'Marketing Spend': '923', 'Promo': 'No Promo'}
# {'Date': '02/12/2020', 'Day_Name': 'Wednesday', 'Visitors': '1955', 'Revenue': '14254', 'Marketing Spend': '1425.4', 'Promo': 'Promotion Red'}
# {'Date': '03/12/2020', 'Day_Name': 'Thursday', 'Visitors': '2171', 'Revenue': '16644', 'Marketing Spend': '1664.4', 'Promo': 'No Promo'}
# {'Date': '04/12/2020', 'Day_Name': 'Friday', 'Visitors': '1975', 'Revenue': '20607', 'Marketing Spend': '2575.875', 'Promo': 'Promotion Blue'}
# {'Date': '05/12/2020', 'Day_Name': 'Saturday', 'Visitors': '1186', 'Revenue': '7765', 'Marketing Spend': '776.5', 'Promo': 'No Promo'}
# {'Date': '06/12/2020', 'Day_Name': 'Sunday', 'Visitors': '1822', 'Revenue': '10075', 'Marketing Spend': '915.9090909', 'Promo': 'Promotion Red'}
# {'Date': '07/12/2020', 'Day_Name': 'Monday', 'Visitors': '1584', 'Revenue': '9612', 'Marketing Spend': '961.2', 'Promo': 'Promotion Red'}
# {'Date': '08/12/2020', 'Day_Name': 'Tuesday', 'Visitors': '1961', 'Revenue': '11601', 'Marketing Spend': '1450.125', 'Promo': 'No Promo'}
# {'Date': '09/12/2020', 'Day_Name': 'Wednesday', 'Visitors': '2464', 'Revenue': '16300', 'Marketing Spend': '1811.111111', 'Promo': 'No Promo'}
# {'Date': '10/12/2020', 'Day_Name': 'Thursday', 'Visitors': '2394', 'Revenue': '17740', 'Marketing Spend': '1971.111111', 'Promo': 'No Promo'}
# {'Date': '11/12/2020', 'Day_Name': 'Friday', 'Visitors': '1322', 'Revenue': '10140', 'Marketing Spend': '1267.5', 'Promo': 'No Promo'}
# {'Date': '12/12/2020', 'Day_Name': 'Saturday', 'Visitors': '1167', 'Revenue': '9097', 'Marketing Spend': '1010.777778', 'Promo': 'Promotion Blue'}
# {'Date': '13/12/2020', 'Day_Name': 'Sunday', 'Visitors': '1163', 'Revenue': '8802', 'Marketing Spend': '880.2', 'Promo': 'Promotion Blue'}
# {'Date': '14/12/2020', 'Day_Name': 'Monday', 'Visitors': '1772', 'Revenue': '11679', 'Marketing Spend': '1297.666667', 'Promo': 'Promotion Red'}
# {'Date': '15/12/2020', 'Day_Name': 'Tuesday', 'Visitors': '1740', 'Revenue': '11952', 'Marketing Spend': '1086.545455', 'Promo': 'Promotion Red'}
# {'Date': '16/12/2020', 'Day_Name': 'Wednesday', 'Visitors': '1317', 'Revenue': '9213', 'Marketing Spend': '1023.666667', 'Promo': 'No Promo'}
# {'Date': '17/12/2020', 'Day_Name': 'Thursday', 'Visitors': '2330', 'Revenue': '17618', 'Marketing Spend': '1601.636364', 'Promo': 'No Promo'}
# {'Date': '18/12/2020', 'Day_Name': 'Friday', 'Visitors': '2056', 'Revenue': '18161', 'Marketing Spend': '2270.125', 'Promo': 'Promotion Blue'}
# {'Date': '19/12/2020', 'Day_Name': 'Saturday', 'Visitors': '1191', 'Revenue': '8800', 'Marketing Spend': '880', 'Promo': 'Promotion Red'}
# {'Date': '20/12/2020', 'Day_Name': 'Sunday', 'Visitors': '1828', 'Revenue': '11737', 'Marketing Spend': '1304.111111', 'Promo': 'No Promo'}
# {'Date': '21/12/2020', 'Day_Name': 'Monday', 'Visitors': '1605', 'Revenue': '12038', 'Marketing Spend': '1203.8', 'Promo': 'Promotion Blue'}
# {'Date': '22/12/2020', 'Day_Name': 'Tuesday', 'Visitors': '1571', 'Revenue': '10245', 'Marketing Spend': '1024.5', 'Promo': 'Promotion Red'}
# {'Date': '23/12/2020', 'Day_Name': 'Wednesday', 'Visitors': '1288', 'Revenue': '11817', 'Marketing Spend': '1181.7', 'Promo': 'Promotion Blue'}
# {'Date': '24/12/2020', 'Day_Name': 'Thursday', 'Visitors': '2556', 'Revenue': '19550', 'Marketing Spend': '1955', 'Promo': 'No Promo'}
# {'Date': '25/12/2020', 'Day_Name': 'Friday', 'Visitors': '2152', 'Revenue': '21031', 'Marketing Spend': '2336.777778', 'Promo': 'Promotion Blue'}
# {'Date': '26/12/2020', 'Day_Name': 'Saturday', 'Visitors': '2678', 'Revenue': '36283', 'Marketing Spend': '4535.375', 'Promo': 'Promotion Blue'}
# {'Date': '27/12/2020', 'Day_Name': 'Sunday', 'Visitors': '2020', 'Revenue': '23014', 'Marketing Spend': '2557.111111', 'Promo': 'Promotion Blue'}
# {'Date': '28/12/2020', 'Day_Name': 'Monday', 'Visitors': '1480', 'Revenue': '8611', 'Marketing Spend': '782.8181818', 'Promo': 'No Promo'}
# {'Date': '29/12/2020', 'Day_Name': 'Tuesday', 'Visitors': '1226', 'Revenue': '7793', 'Marketing Spend': '779.3', 'Promo': 'Promotion Red'}
# {'Date': '30/12/2020', 'Day_Name': 'Wednesday', 'Visitors': '1328', 'Revenue': '9180', 'Marketing Spend': '918', 'Promo': 'Promotion Red'}
# {'Date': '31/12/2020', 'Day_Name': 'Thursday', 'Visitors': '2295', 'Revenue': '19280', 'Marketing Spend': '2410', 'Promo': 'No Promo'}
# {'Date': '01/01/2021', 'Day_Name': 'Friday', 'Visitors': '2032', 'Revenue': '21428', 'Marketing Spend': '1948', 'Promo': 'Promotion Blue'}
# {'Date': '02/01/2021', 'Day_Name': 'Saturday', 'Visitors': '1030', 'Revenue': '9062', 'Marketing Spend': '1006.888889', 'Promo': 'Promotion Blue'}
# {'Date': '03/01/2021', 'Day_Name': 'Sunday', 'Visitors': '1442', 'Revenue': '9952', 'Marketing Spend': '1244', 'Promo': 'Promotion Blue'}
# {'Date': '04/01/2021', 'Day_Name': 'Monday', 'Visitors': '1476', 'Revenue': '8563', 'Marketing Spend': '1070.375', 'Promo': 'No Promo'}
# {'Date': '05/01/2021', 'Day_Name': 'Tuesday', 'Visitors': '1272', 'Revenue': '9418', 'Marketing Spend': '856.1818182', 'Promo': 'Promotion Red'}
# {'Date': '06/01/2021', 'Day_Name': 'Wednesday', 'Visitors': '2054', 'Revenue': '25766', 'Marketing Spend': '2862.888889', 'Promo': 'Promotion Red'}
# {'Date': '07/01/2021', 'Day_Name': 'Thursday', 'Visitors': '4139', 'Revenue': '30146', 'Marketing Spend': '3014.6', 'Promo': 'No Promo'}
# {'Date': '08/01/2021', 'Day_Name': 'Friday', 'Visitors': '2286', 'Revenue': '15962', 'Marketing Spend': '1596.2', 'Promo': 'No Promo'}
# {'Date': '09/01/2021', 'Day_Name': 'Saturday', 'Visitors': '1371', 'Revenue': '11249', 'Marketing Spend': '1406.125', 'Promo': 'Promotion Blue'}
# {'Date': '10/01/2021', 'Day_Name': 'Sunday', 'Visitors': '1484', 'Revenue': '12129', 'Marketing Spend': '1516.125', 'Promo': 'Promotion Red'}
# {'Date': '11/01/2021', 'Day_Name': 'Monday', 'Visitors': '1571', 'Revenue': '7300', 'Marketing Spend': '912.5', 'Promo': 'No Promo'}
# {'Date': '12/01/2021', 'Day_Name': 'Tuesday', 'Visitors': '1454', 'Revenue': '8702', 'Marketing Spend': '870.2', 'Promo': 'Promotion Red'}
# {'Date': '13/01/2021', 'Day_Name': 'Wednesday', 'Visitors': '1243', 'Revenue': '7509', 'Marketing Spend': '834.3333333', 'Promo': 'No Promo'}
# {'Date': '14/01/2021', 'Day_Name': 'Thursday', 'Visitors': '2753', 'Revenue': '22797', 'Marketing Spend': '2072.454545', 'Promo': 'Promotion Red'}
# {'Date': '15/01/2021', 'Day_Name': 'Friday', 'Visitors': '2312', 'Revenue': '21245', 'Marketing Spend': '2655.625', 'Promo': 'Promotion Blue'}
# {'Date': '16/01/2021', 'Day_Name': 'Saturday', 'Visitors': '1414', 'Revenue': '11699', 'Marketing Spend': '1169.9', 'Promo': 'Promotion Blue'}
# {'Date': '17/01/2021', 'Day_Name': 'Sunday', 'Visitors': '1524', 'Revenue': '9602', 'Marketing Spend': '960.2', 'Promo': 'Promotion Red'}
# {'Date': '18/01/2021', 'Day_Name': 'Monday', 'Visitors': '1469', 'Revenue': '8633', 'Marketing Spend': '784.8181818', 'Promo': 'Promotion Red'}
# {'Date': '19/01/2021', 'Day_Name': 'Tuesday', 'Visitors': '1302', 'Revenue': '7287', 'Marketing Spend': '728.7', 'Promo': 'Promotion Red'}
# {'Date': '20/01/2021', 'Day_Name': 'Wednesday', 'Visitors': '1659', 'Revenue': '9261', 'Marketing Spend': '841.9090909', 'Promo': 'No Promo'}
# {'Date': '21/01/2021', 'Day_Name': 'Thursday', 'Visitors': '2120', 'Revenue': '14770', 'Marketing Spend': '1641.111111', 'Promo': 'No Promo'}
# {'Date': '22/01/2021', 'Day_Name': 'Friday', 'Visitors': '2482', 'Revenue': '24417', 'Marketing Spend': '2713', 'Promo': 'Promotion Blue'}
# {'Date': '23/01/2021', 'Day_Name': 'Saturday', 'Visitors': '1820', 'Revenue': '11329', 'Marketing Spend': '1029.909091', 'Promo': 'No Promo'}
# {'Date': '24/01/2021', 'Day_Name': 'Sunday', 'Visitors': '1628', 'Revenue': '12445', 'Marketing Spend': '1244.5', 'Promo': 'Promotion Red'}
# {'Date': '25/01/2021', 'Day_Name': 'Monday', 'Visitors': '1430', 'Revenue': '10925', 'Marketing Spend': '1365.625', 'Promo': 'Promotion Blue'}
# {'Date': '26/01/2021', 'Day_Name': 'Tuesday', 'Visitors': '488', 'Revenue': '2898', 'Marketing Spend': '322', 'Promo': 'No Promo'}
# {'Date': '27/01/2021', 'Day_Name': 'Wednesday', 'Visitors': '1084', 'Revenue': '7049', 'Marketing Spend': '881.125', 'Promo': 'No Promo'}
# {'Date': '28/01/2021', 'Day_Name': 'Thursday', 'Visitors': '1864', 'Revenue': '12832', 'Marketing Spend': '1425.777778', 'Promo': 'No Promo'}
# {'Date': '29/01/2021', 'Day_Name': 'Friday', 'Visitors': '1844', 'Revenue': '13024', 'Marketing Spend': '1447.111111', 'Promo': 'No Promo'}
# {'Date': '30/01/2021', 'Day_Name': 'Saturday', 'Visitors': '1065', 'Revenue': '7074', 'Marketing Spend': '786', 'Promo': 'No Promo'}
# {'Date': '31/01/2021', 'Day_Name': 'Sunday', 'Visitors': '1582', 'Revenue': '9316', 'Marketing Spend': '1035.111111', 'Promo': 'No Promo'}
# {'Date': '01/02/2021', 'Day_Name': 'Monday', 'Visitors': '1407', 'Revenue': '10479', 'Marketing Spend': '1047.9', 'Promo': 'Promotion Blue'}
# {'Date': '02/02/2021', 'Day_Name': 'Tuesday', 'Visitors': '1496', 'Revenue': '12783', 'Marketing Spend': '1162.090909', 'Promo': 'Promotion Blue'}
# {'Date': '03/02/2021', 'Day_Name': 'Wednesday', 'Visitors': '2176', 'Revenue': '18678', 'Marketing Spend': '1698', 'Promo': 'Promotion Blue'}
# {'Date': '04/02/2021', 'Day_Name': 'Thursday', 'Visitors': '2010', 'Revenue': '14696', 'Marketing Spend': '1336', 'Promo': 'No Promo'}
# {'Date': '05/02/2021', 'Day_Name': 'Friday', 'Visitors': '2015', 'Revenue': '17661', 'Marketing Spend': '2207.625', 'Promo': 'Promotion Red'}
# {'Date': '06/02/2021', 'Day_Name': 'Saturday', 'Visitors': '1488', 'Revenue': '9095', 'Marketing Spend': '909.5', 'Promo': 'Promotion Red'}
# {'Date': '07/02/2021', 'Day_Name': 'Sunday', 'Visitors': '1608', 'Revenue': '9199', 'Marketing Spend': '836.2727273', 'Promo': 'No Promo'}
# {'Date': '08/02/2021', 'Day_Name': 'Monday', 'Visitors': '1337', 'Revenue': '9294', 'Marketing Spend': '929.4', 'Promo': 'No Promo'}
# {'Date': '09/02/2021', 'Day_Name': 'Tuesday', 'Visitors': '2266', 'Revenue': '20860', 'Marketing Spend': '2317.777778', 'Promo': 'Promotion Blue'}
# {'Date': '10/02/2021', 'Day_Name': 'Wednesday', 'Visitors': '1925', 'Revenue': '13602', 'Marketing Spend': '1511.333333', 'Promo': 'Promotion Blue'}
# {'Date': '11/02/2021', 'Day_Name': 'Thursday', 'Visitors': '826', 'Revenue': '6546', 'Marketing Spend': '818.25', 'Promo': 'No Promo'}
# {'Date': '12/02/2021', 'Day_Name': 'Friday', 'Visitors': '1387', 'Revenue': '10310', 'Marketing Spend': '937.2727273', 'Promo': 'No Promo'}
# {'Date': '13/02/2021', 'Day_Name': 'Saturday', 'Visitors': '599', 'Revenue': '3392', 'Marketing Spend': '424', 'Promo': 'No Promo'}
# {'Date': '14/02/2021', 'Day_Name': 'Sunday', 'Visitors': '968', 'Revenue': '5772', 'Marketing Spend': '524.7272727', 'Promo': 'Promotion Red'}
# {'Date': '15/02/2021', 'Day_Name': 'Monday', 'Visitors': '1482', 'Revenue': '9987', 'Marketing Spend': '907.9090909', 'Promo': 'Promotion Red'}
# {'Date': '16/02/2021', 'Day_Name': 'Tuesday', 'Visitors': '1420', 'Revenue': '8422', 'Marketing Spend': '935.7777778', 'Promo': 'No Promo'}
# {'Date': '17/02/2021', 'Day_Name': 'Wednesday', 'Visitors': '1171', 'Revenue': '7809', 'Marketing Spend': '780.9', 'Promo': 'No Promo'}
# {'Date': '18/02/2021', 'Day_Name': 'Thursday', 'Visitors': '2395', 'Revenue': '24247', 'Marketing Spend': '3030.875', 'Promo': 'Promotion Blue'}
# {'Date': '19/02/2021', 'Day_Name': 'Friday', 'Visitors': '2029', 'Revenue': '14706', 'Marketing Spend': '1336.909091', 'Promo': 'No Promo'}
# {'Date': '20/02/2021', 'Day_Name': 'Saturday', 'Visitors': '1047', 'Revenue': '6427', 'Marketing Spend': '803.375', 'Promo': 'No Promo'}
# {'Date': '21/02/2021', 'Day_Name': 'Sunday', 'Visitors': '1464', 'Revenue': '7462', 'Marketing Spend': '829.1111111', 'Promo': 'No Promo'}
# {'Date': '22/02/2021', 'Day_Name': 'Monday', 'Visitors': '1428', 'Revenue': '8371', 'Marketing Spend': '837.1', 'Promo': 'No Promo'}
# {'Date': '23/02/2021', 'Day_Name': 'Tuesday', 'Visitors': '1154', 'Revenue': '9135', 'Marketing Spend': '1015', 'Promo': 'Promotion Red'}
# {'Date': '24/02/2021', 'Day_Name': 'Wednesday', 'Visitors': '1841', 'Revenue': '13719', 'Marketing Spend': '1371.9', 'Promo': 'Promotion Blue'}
# {'Date': '25/02/2021', 'Day_Name': 'Thursday', 'Visitors': '2248', 'Revenue': '20237', 'Marketing Spend': '2529.625', 'Promo': 'Promotion Blue'}
# {'Date': '26/02/2021', 'Day_Name': 'Friday', 'Visitors': '2553', 'Revenue': '26608', 'Marketing Spend': '2418.909091', 'Promo': 'Promotion Blue'}
# {'Date': '27/02/2021', 'Day_Name': 'Saturday', 'Visitors': '1797', 'Revenue': '12789', 'Marketing Spend': '1278.9', 'Promo': 'Promotion Red'}
# {'Date': '28/02/2021', 'Day_Name': 'Sunday', 'Visitors': '1912', 'Revenue': '12036', 'Marketing Spend': '1337.333333', 'Promo': 'No Promo'}
# {'Date': '01/03/2021', 'Day_Name': 'Monday', 'Visitors': '1786', 'Revenue': '13212', 'Marketing Spend': '1468', 'Promo': 'Promotion Blue'}
# {'Date': '02/03/2021', 'Day_Name': 'Tuesday', 'Visitors': '1096', 'Revenue': '6155', 'Marketing Spend': '615.5', 'Promo': 'No Promo'}
# {'Date': '03/03/2021', 'Day_Name': 'Wednesday', 'Visitors': '1068', 'Revenue': '8223', 'Marketing Spend': '822.3', 'Promo': 'Promotion Red'}
# {'Date': '04/03/2021', 'Day_Name': 'Thursday', 'Visitors': '1976', 'Revenue': '16727', 'Marketing Spend': '1672.7', 'Promo': 'Promotion Blue'}
# {'Date': '05/03/2021', 'Day_Name': 'Friday', 'Visitors': '1806', 'Revenue': '15474', 'Marketing Spend': '1719.333333', 'Promo': 'Promotion Blue'}
# {'Date': '06/03/2021', 'Day_Name': 'Saturday', 'Visitors': '1621', 'Revenue': '12850', 'Marketing Spend': '1427.777778', 'Promo': 'Promotion Blue'}
# {'Date': '07/03/2021', 'Day_Name': 'Sunday', 'Visitors': '1001', 'Revenue': '6681', 'Marketing Spend': '668.1', 'Promo': 'No Promo'}
# {'Date': '08/03/2021', 'Day_Name': 'Monday', 'Visitors': '1477', 'Revenue': '8338', 'Marketing Spend': '926.4444444', 'Promo': 'No Promo'}
# {'Date': '09/03/2021', 'Day_Name': 'Tuesday', 'Visitors': '1401', 'Revenue': '8569', 'Marketing Spend': '779', 'Promo': 'No Promo'}
# {'Date': '10/03/2021', 'Day_Name': 'Wednesday', 'Visitors': '2190', 'Revenue': '17752', 'Marketing Spend': '1613.818182', 'Promo': 'Promotion Red'}
# {'Date': '11/03/2021', 'Day_Name': 'Thursday', 'Visitors': '2439', 'Revenue': '25704', 'Marketing Spend': '2570.4', 'Promo': 'Promotion Blue'}
# {'Date': '12/03/2021', 'Day_Name': 'Friday', 'Visitors': '2220', 'Revenue': '15302', 'Marketing Spend': '1912.75', 'Promo': 'No Promo'}
# {'Date': '13/03/2021', 'Day_Name': 'Saturday', 'Visitors': '2732', 'Revenue': '28196', 'Marketing Spend': '3524.5', 'Promo': 'Promotion Blue'}
# {'Date': '14/03/2021', 'Day_Name': 'Sunday', 'Visitors': '967', 'Revenue': '7878', 'Marketing Spend': '787.8', 'Promo': 'Promotion Blue'}
# {'Date': '15/03/2021', 'Day_Name': 'Monday', 'Visitors': '1544', 'Revenue': '8083', 'Marketing Spend': '734.8181818', 'Promo': 'No Promo'}
# {'Date': '16/03/2021', 'Day_Name': 'Tuesday', 'Visitors': '1455', 'Revenue': '7518', 'Marketing Spend': '939.75', 'Promo': 'No Promo'}
# {'Date': '17/03/2021', 'Day_Name': 'Wednesday', 'Visitors': '2194', 'Revenue': '14608', 'Marketing Spend': '1826', 'Promo': 'No Promo'}
# {'Date': '18/03/2021', 'Day_Name': 'Thursday', 'Visitors': '1923', 'Revenue': '14909', 'Marketing Spend': '1490.9', 'Promo': 'Promotion Red'}
# {'Date': '19/03/2021', 'Day_Name': 'Friday', 'Visitors': '685', 'Revenue': '5903', 'Marketing Spend': '590.3', 'Promo': 'Promotion Red'}
# {'Date': '20/03/2021', 'Day_Name': 'Saturday', 'Visitors': '543', 'Revenue': '4169', 'Marketing Spend': '521.125', 'Promo': 'Promotion Red'}
# {'Date': '21/03/2021', 'Day_Name': 'Sunday', 'Visitors': '1472', 'Revenue': '9486', 'Marketing Spend': '862.3636364', 'Promo': 'Promotion Red'}
# {'Date': '22/03/2021', 'Day_Name': 'Monday', 'Visitors': '1368', 'Revenue': '9209', 'Marketing Spend': '1151.125', 'Promo': 'Promotion Red'}
# {'Date': '23/03/2021', 'Day_Name': 'Tuesday', 'Visitors': '1454', 'Revenue': '11494', 'Marketing Spend': '1277.111111', 'Promo': 'Promotion Blue'}
# {'Date': '24/03/2021', 'Day_Name': 'Wednesday', 'Visitors': '2080', 'Revenue': '15190', 'Marketing Spend': '1519', 'Promo': 'Promotion Red'}
# {'Date': '25/03/2021', 'Day_Name': 'Thursday', 'Visitors': '2611', 'Revenue': '22701', 'Marketing Spend': '2837.625', 'Promo': 'Promotion Red'}
# {'Date': '26/03/2021', 'Day_Name': 'Friday', 'Visitors': '2434', 'Revenue': '22587', 'Marketing Spend': '2258.7', 'Promo': 'Promotion Blue'}
# {'Date': '27/03/2021', 'Day_Name': 'Saturday', 'Visitors': '1437', 'Revenue': '7820', 'Marketing Spend': '868.8888889', 'Promo': 'No Promo'}
# {'Date': '28/03/2021', 'Day_Name': 'Sunday', 'Visitors': '1642', 'Revenue': '14587', 'Marketing Spend': '1620.777778', 'Promo': 'Promotion Blue'}
# {'Date': '29/03/2021', 'Day_Name': 'Monday', 'Visitors': '1320', 'Revenue': '9262', 'Marketing Spend': '842', 'Promo': 'Promotion Red'}
# {'Date': '30/03/2021', 'Day_Name': 'Tuesday', 'Visitors': '1363', 'Revenue': '7794', 'Marketing Spend': '866', 'Promo': 'No Promo'}
# {'Date': '31/03/2021', 'Day_Name': 'Wednesday', 'Visitors': '2068', 'Revenue': '14957', 'Marketing Spend': '1869.625', 'Promo': 'Promotion Red'}
# {'Date': '01/04/2021', 'Day_Name': 'Thursday', 'Visitors': '2311', 'Revenue': '23368', 'Marketing Spend': '2921', 'Promo': 'Promotion Blue'}
# {'Date': '02/04/2021', 'Day_Name': 'Friday', 'Visitors': '2091', 'Revenue': '15782', 'Marketing Spend': '1972.75', 'Promo': 'No Promo'}
# {'Date': '03/04/2021', 'Day_Name': 'Saturday', 'Visitors': '1532', 'Revenue': '12027', 'Marketing Spend': '1336.333333', 'Promo': 'Promotion Red'}
# {'Date': '04/04/2021', 'Day_Name': 'Sunday', 'Visitors': '1406', 'Revenue': '7545', 'Marketing Spend': '754.5', 'Promo': 'No Promo'}
# {'Date': '05/04/2021', 'Day_Name': 'Monday', 'Visitors': '1180', 'Revenue': '8396', 'Marketing Spend': '763.2727273', 'Promo': 'Promotion Red'}
# {'Date': '06/04/2021', 'Day_Name': 'Tuesday', 'Visitors': '1244', 'Revenue': '8828', 'Marketing Spend': '882.8', 'Promo': 'Promotion Red'}
# {'Date': '07/04/2021', 'Day_Name': 'Wednesday', 'Visitors': '1812', 'Revenue': '16777', 'Marketing Spend': '1677.7', 'Promo': 'Promotion Red'}
# {'Date': '08/04/2021', 'Day_Name': 'Thursday', 'Visitors': '2273', 'Revenue': '19843', 'Marketing Spend': '1803.909091', 'Promo': 'Promotion Red'}
# {'Date': '09/04/2021', 'Day_Name': 'Friday', 'Visitors': '2158', 'Revenue': '23870', 'Marketing Spend': '2652.222222', 'Promo': 'Promotion Blue'}
# {'Date': '10/04/2021', 'Day_Name': 'Saturday', 'Visitors': '1625', 'Revenue': '10431', 'Marketing Spend': '1043.1', 'Promo': 'No Promo'}
# {'Date': '11/04/2021', 'Day_Name': 'Sunday', 'Visitors': '1485', 'Revenue': '11221', 'Marketing Spend': '1020.090909', 'Promo': 'Promotion Blue'}
# {'Date': '12/04/2021', 'Day_Name': 'Monday', 'Visitors': '1499', 'Revenue': '10027', 'Marketing Spend': '1114.111111', 'Promo': 'Promotion Red'}
# {'Date': '13/04/2021', 'Day_Name': 'Tuesday', 'Visitors': '1511', 'Revenue': '11484', 'Marketing Spend': '1148.4', 'Promo': 'Promotion Blue'}
# {'Date': '14/04/2021', 'Day_Name': 'Wednesday', 'Visitors': '1803', 'Revenue': '16347', 'Marketing Spend': '1634.7', 'Promo': 'Promotion Blue'}
# {'Date': '15/04/2021', 'Day_Name': 'Thursday', 'Visitors': '2101', 'Revenue': '15828', 'Marketing Spend': '1758.666667', 'Promo': 'No Promo'}
# {'Date': '16/04/2021', 'Day_Name': 'Friday', 'Visitors': '1915', 'Revenue': '14714', 'Marketing Spend': '1337.636364', 'Promo': 'No Promo'}
# {'Date': '17/04/2021', 'Day_Name': 'Saturday', 'Visitors': '1509', 'Revenue': '9520', 'Marketing Spend': '865.4545455', 'Promo': 'No Promo'}
# {'Date': '18/04/2021', 'Day_Name': 'Sunday', 'Visitors': '1399', 'Revenue': '12251', 'Marketing Spend': '1531.375', 'Promo': 'Promotion Blue'}
# {'Date': '19/04/2021', 'Day_Name': 'Monday', 'Visitors': '1648', 'Revenue': '9645', 'Marketing Spend': '964.5', 'Promo': 'Promotion Red'}
# {'Date': '20/04/2021', 'Day_Name': 'Tuesday', 'Visitors': '1154', 'Revenue': '7058', 'Marketing Spend': '784.2222222', 'Promo': 'No Promo'}
# {'Date': '21/04/2021', 'Day_Name': 'Wednesday', 'Visitors': '1122', 'Revenue': '6591', 'Marketing Spend': '732.3333333', 'Promo': 'No Promo'}
# {'Date': '22/04/2021', 'Day_Name': 'Thursday', 'Visitors': '2302', 'Revenue': '24506', 'Marketing Spend': '2227.818182', 'Promo': 'Promotion Blue'}
# {'Date': '23/04/2021', 'Day_Name': 'Friday', 'Visitors': '1942', 'Revenue': '14358', 'Marketing Spend': '1595.333333', 'Promo': 'No Promo'}
# {'Date': '24/04/2021', 'Day_Name': 'Saturday', 'Visitors': '1345', 'Revenue': '9360', 'Marketing Spend': '850.9090909', 'Promo': 'Promotion Red'}
# {'Date': '25/04/2021', 'Day_Name': 'Sunday', 'Visitors': '1166', 'Revenue': '11650', 'Marketing Spend': '1059.090909', 'Promo': 'Promotion Blue'}
# {'Date': '26/04/2021', 'Day_Name': 'Monday', 'Visitors': '1105', 'Revenue': '8438', 'Marketing Spend': '843.8', 'Promo': 'No Promo'}
# {'Date': '27/04/2021', 'Day_Name': 'Tuesday', 'Visitors': '1256', 'Revenue': '8046', 'Marketing Spend': '731.4545455', 'Promo': 'Promotion Red'}
# {'Date': '28/04/2021', 'Day_Name': 'Wednesday', 'Visitors': '1236', 'Revenue': '9540', 'Marketing Spend': '1060', 'Promo': 'Promotion Blue'}
# {'Date': '29/04/2021', 'Day_Name': 'Thursday', 'Visitors': '2139', 'Revenue': '22655', 'Marketing Spend': '2059.545455', 'Promo': 'Promotion Blue'}
# {'Date': '30/04/2021', 'Day_Name': 'Friday', 'Visitors': '1836', 'Revenue': '19167', 'Marketing Spend': '1916.7', 'Promo': 'Promotion Blue'}
# {'Date': '01/05/2021', 'Day_Name': 'Saturday', 'Visitors': '1380', 'Revenue': '8862', 'Marketing Spend': '805.6363636', 'Promo': 'No Promo'}
# {'Date': '02/05/2021', 'Day_Name': 'Sunday', 'Visitors': '1423', 'Revenue': '12111', 'Marketing Spend': '1513.875', 'Promo': 'Promotion Red'}
# {'Date': '03/05/2021', 'Day_Name': 'Monday', 'Visitors': '1382', 'Revenue': '11273', 'Marketing Spend': '1024.818182', 'Promo': 'Promotion Red'}
# {'Date': '04/05/2021', 'Day_Name': 'Tuesday', 'Visitors': '2152', 'Revenue': '13805', 'Marketing Spend': '1533.888889', 'Promo': 'No Promo'}
# {'Date': '05/05/2021', 'Day_Name': 'Wednesday', 'Visitors': '1400', 'Revenue': '11196', 'Marketing Spend': '1119.6', 'Promo': 'No Promo'}
# {'Date': '06/05/2021', 'Day_Name': 'Thursday', 'Visitors': '2244', 'Revenue': '18611', 'Marketing Spend': '2067.888889', 'Promo': 'Promotion Red'}
# {'Date': '07/05/2021', 'Day_Name': 'Friday', 'Visitors': '2023', 'Revenue': '14502', 'Marketing Spend': '1450.2', 'Promo': 'No Promo'}
# {'Date': '08/05/2021', 'Day_Name': 'Saturday', 'Visitors': '1483', 'Revenue': '8975', 'Marketing Spend': '1121.875', 'Promo': 'No Promo'}
# {'Date': '09/05/2021', 'Day_Name': 'Sunday', 'Visitors': '1303', 'Revenue': '6968', 'Marketing Spend': '871', 'Promo': 'No Promo'}

# %% [markdown]
# This wraps up a brief introduction to working with CSV files using the `csv` library in Python. There are additional details to be aware of (such as different delimiter and quoting characters), so refer to the Python documentation for the `csv` module for more detailed information.
#
# Remember, CSV is a common data format, and the ability to accurately and efficiently read and write CSV files is a key skill for any data engineer.
#
# ## Memory Efficiency and CSV Module in Python
#
# CSV files are commonly used for storing tabular data. In Python, the `csv` module provides functionality to both read from and write to CSV files.
#
# ### DictReader and DictWriter
#
# While the `DictReader` and `DictWriter` classes of the `csv` module provide convenience for accessing data, they may not be the most memory-efficient way of processing large CSV files.
#
# The `DictReader` reads in each row of the CSV file as a dictionary, with the keys corresponding to the header row and the values corresponding to the respective values in the current row. This means that for each row, a new dictionary is created. If you have a large number of rows, this can consume quite a lot of memory.
#
# The `DictWriter` works similarly when writing CSV files. It uses a dictionary for each row of data. If the data set you're dealing with is large, this can also lead to high memory usage.
#
# ### Memory Efficient Alternatives
#
# If you're dealing with a large CSV file and memory usage is a concern, consider using the basic `csv.reader` and `csv.writer` classes instead. These classes deal with lists instead of dictionaries, which makes them more memory-efficient.

# %%
with open('large_file.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        # process the row

# %% [markdown]
# In the above code, `row` is a list of values in the current row. You can access individual fields by index (for example, `row[0]` for the first field).
#
# If you still need to work with data on a field-name basis, consider combining `csv.reader` with a named tuple. Named tuples are more memory-efficient than dictionaries because they are immutable and do not need to store the field names for each instance:

# %%
from collections import namedtuple

with open(file_path, 'r') as f:
    reader = csv.reader(f)
    headers = next(reader)
    headers = [name.replace(" ", "_") for name in headers]
    Row = namedtuple('Row', headers)
    
    with open("../data/marketing_processed.csv", "w", newline="") as f_processed:
        writer = csv.writer(f_processed, delimiter='\t')
        for row in reader:
            row = Row(*row)
            # process the row
            processed_row = [
                row.Date.replace("/", "-"), 
                row.Day_Name, 
                row.Visitors, 
                row.Revenue, 
                row.Marketing_Spend, 
                row.Promo]
            writer.writerow(processed_row)

# %%
headers
# Out:
# ['Date', 'Day_Name', 'Visitors', 'Revenue', 'Marketing_Spend', 'Promo']

# %% [markdown]
# ### Generators
#
# Generators can be extremely useful when dealing with large amounts of data. Generators allow you to create a function that can be paused, return an intermediate result, and then resumed where it left off, thereby allowing it to generate a sequence of results over time, rather than computing them all at once and holding them in memory.
#
# Here's how you can use a generator with the csv module to read a large file:

# %%
def csv_reader(file_name):
    for row in open(file_name, "r"):
        yield row

csv_gen = csv_reader("large_file.csv")

for row in csv_gen:
    print(row) # process the row here

# %% [markdown]
# In the above example, `csv_reader` is a generator function that reads a file line by line. Each line is yielded one at a time and processed, which is much more memory-efficient than reading the entire file into memory at once.

# %% [markdown]
# > Content created by [**Carlos Cruz-Maldonado**](https://www.linkedin.com/in/carloscruzmaldonado/).
# > I am available to answer any questions or provide further assistance.
# > Feel free to reach out to me at any time.
